# %% [markdown]
# <img src=".\EMODnet_compact_colour (1).png" align="right" width="50%"></img>
# # EMODnet OGC services Workshop
# ### Tier 2: How to use OGC webservices offered by EMODnet in your data analysis

# %% [markdown]
# ## 3. Subset & download data using OGC Web Feature and Coverage Services (WFS/WCS)

# %% [markdown]
# The OWSLib library is a python library that makes accessing data and metadata through OGC services possible. The library abstracts all of the traditional HTTP API calls into programmatic function calls. We will be using this library throughout the tutorial to interact with the EMODnet OGC services.
#
# The library is available from GitHub @  https://github.com/geopython/OWSLib

# %%
from owslib.wfs import WebFeatureService
from owslib.wcs import WebCoverageService
from owslib.wms import WebMapService
from matplotlib import pyplot as plt

# %% [markdown]
# ## 3.1 Get vector data with WFS
# #### Working with EMODnet Human Activities datasets

# %% [markdown]
# #### Create a WebFeatureService (WFS) object
# Note that we use version 1.1.0 as in OWSLib this version has support for [OGC Filter Encoding](https://www.ogc.org/standards/filter)

# %%
wfs = WebFeatureService('https://ows.emodnet-humanactivities.eu/wfs', version = '1.1.0')

# %% [markdown]
# #### Find out what the WFS has to offer. Service metadata:

# %%
print(wfs.identification.type)
print(wfs.identification.version)
print(wfs.identification.title)
print(wfs.identification.abstract)
# Out:
# WFS
# 1.1.0
# GeoServer Web Feature Service
# This is the reference implementation of WFS 1.0.0 and WFS 1.1.0, supports all WFS operations including Transaction.

# %% [markdown]
# #### See available methods

# %%
[operation.name for operation in wfs.operations]
# Out:
# ['GetCapabilities',
#  'DescribeFeatureType',
#  'GetFeature',
#  'GetGmlObject',
#  'LockFeature',
#  'GetFeatureWithLock',
#  'Transaction']

# %% [markdown]
# #### Get available formats

# %%
wfs.getOperationByName('GetFeature').parameters
# Out:
# {'resultType': {'values': ['results', 'hits']},
#  'outputFormat': {'values': ['text/xml; subtype=gml/3.1.1',
#    'GML2',
#    'KML',
#    'SHAPE-ZIP',
#    'application/gml+xml; version=3.2',
#    'application/json',
#    'application/vnd.google-earth.kml xml',
#    'application/vnd.google-earth.kml+xml',
#    'csv',
#    'gml3',
#    'gml32',
#    'json',
#    'text/csv',
#    'text/xml; subtype=gml/2.1.2',
#    'text/xml; subtype=gml/3.2']}}

# %% [markdown]
# #### Find out what vector datasets (FeatureTypes) are available
# Note that only vector datasets that are uploaded trhough the Human Activities portal and are publicly available are shown

# %%
list(wfs.contents)
# Out:
# ['emodnet:activelicenses',
#  'emodnet:advisorycouncils',
#  'emodnet:aquaculture',
#  'emodnet:baltic',
#  'emodnet:blacksea',
#  'emodnet:longdistancefleet',
#  'emodnet:market',
#  'emodnet:mediterranean',
#  'emodnet:northsea',
#  'emodnet:northwesternwaters',
#  'emodnet:outermostregions',
#  'emodnet:pelagicstocks',
#  'emodnet:southwesternwaters',
#  'emodnet:aggregateareas',
#  'emodnet:aggregates',
#  'emodnet:fishingbeamtrawls',
#  'emodnet:fishingbottomottertrawls',
#  'emodnet:fishingbottomseines',
#  'emodnet:fishingdredges',
#  'emodnet:fishingpelagic',
#  'emodnet:fishingstaticgears',
#  'emodnet:fishingsubsurface',
#  'emodnet:fishingsurface',
#  'emodnet:barcelona',
#  'emodnet:hydrocarbons',
#  'emodnet:bucharest',
#  'emodnet:desalination',
#  'emodnet:dischargepoints',
#  'emodnet:dredgespoil',
#  'emodnet:dredgespoilpoly',
#  'emodnet:dredging',
#  'emodnet:munitions',
#  'emodnet:munitionspoly',
#  'emodnet:emeraldnetwork',
#  'emodnet:faoareas',
#  'emodnet:finfish',
#  'emodnet:fishsales',
#  'emodnet:divisioncatches',
#  'emodnet:majorcatches',
#  'emodnet:subareacatches',
#  'emodnet:subdivisioncatches',
#  'emodnet:subunitcatches',
#  'emodnet:divisioncatchesbycountry',
#  'emodnet:divisioncatchesbyspecies',
#  'emodnet:divisioneffort',
#  'emodnet:gfcmsubareaeffort',
#  'emodnet:majoreffort',
#  'emodnet:subareaeffort',
#  'emodnet:subdivisioneffort',
#  'emodnet:subuniteffort',
#  'emodnet:freshwater',
#  'emodnet:helcom',
#  'emodnet:heritageshipwrecks',
#  'emodnet:icesareas',
#  'emodnet:intconventions',
#  'emodnet:lighthouses',
#  'emodnet:reportingunits',
#  'emodnet:mspspatialplan',
#  'emodnet:mspzoningpoly',
#  'emodnet:mspzoningline',
#  'emodnet:mspzoninglocs',
#  'emodnet:macroalgae',
#  'emodnet:portgoods',
#  'emodnet:portlocations',
#  'emodnet:portpassengers',
#  'emodnet:portvessels',
#  'emodnet:microalgae',
#  'emodnet:militaryareas',
#  'emodnet:militaryareaspoly',
#  'emodnet:cddaareas',
#  'emodnet:natura2000areas',
#  'emodnet:nuclear',
#  'emodnet:ospar',
#  'emodnet:oenergy',
#  'emodnet:oenergytests',
#  'emodnet:platforms',
#  'emodnet:pipelines',
#  'emodnet:pcablesbshcontis',
#  'emodnet:pcablesshom',
#  'emodnet:pcablesrijks',
#  'emodnet:pcablesnve',
#  'emodnet:marineprotectedareas',
#  'emodnet:shellfishlics',
#  'emodnet:shellfish',
#  'emodnet:shellfishwfdareas',
#  'emodnet:spirulina',
#  'emodnet:bathingwaters',
#  'emodnet:bshcontiscables',
#  'emodnet:cicacables',
#  'emodnet:shomcables',
#  'emodnet:sigcables',
#  'emodnet:maltacables',
#  'emodnet:rijkscables',
#  'emodnet:ukfibrecables',
#  'emodnet:treatmentplants',
#  'emodnet:wasteatports',
#  'emodnet:windfarms',
#  'emodnet:windfarmspoly',
#  'emodnet:wdpaareas']

# %% [markdown]
# #### Select the desired dataset among the list returned above

# %%
# Here we chose the European windfarms dataset presented as georeferenced polygons
dataset = 'emodnet:windfarmspoly'

# %% [markdown]
# #### Get the FeatureType Metadata an Bounding Box:

# %%
print(wfs.contents[dataset].title)
print(wfs.contents[dataset].abstract)
bbox1 = wfs.contents[dataset].boundingBoxWGS84
print (bbox1)
# Out:
# Wind Farms (Polygons)
# The dataset on offshore wind farms in the European seas was created in 2014 by CETMAR for the European Marine Observation and Data Network (EMODnet). It is the result of the aggregation and harmonization of datasets provided by several sources. It is updated every year and it is available for viewing and download on EMODnet web portal (Human Activities, https://emodnet.ec.europa.eu/en/human-activities). The dataset contains points and/or (where available) polygons representing offshore wind farms in the following countries: Belgium, Denmark, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Latvia, Lithuania, Netherlands, Norway, Poland, Portugal, Spain, Sweden and United Kingdom. Each point and polygon has the following attributes (where available): Name, Nº of turbines, Status (Approved, Planned, Dismantled, Construction, Production, Test site), Country, Year, Power (MW), Distance to coast (metres) and Area (square kilometres). The distance to coast (EEA coastline shapefile) has been calculated using the UTM WGS84 Zone projected coordinate system where data fall in.
# (-10.32376766204834, 39.712947845458984, 24.912221908569336, 65.59857177734375)

# %% [markdown]
# #### Get the FeatureType’s schema via `DescribeFeatureType`.
# The dictionary returned is compatible with a [Fiona schema object](https://fiona.readthedocs.io/en/latest/fiona.html#fiona.collection.Collection.schema).

# %%
wfs.get_schema(dataset)
# Out:
# {'properties': {'country': 'string',
#   'n_turbines': 'int',
#   'power_mw': 'decimal',
#   'status': 'string',
#   'year': 'string',
#   'dist_coast': 'decimal',
#   'area_sqkm': 'decimal',
#   'notes': 'string'},
#  'required': [],
#  'geometry': 'GeometryCollection',
#  'geometry_column': 'the_geom'}

# %% [markdown]
# #### Subset data with a bounding box

# %%
# Subset data with a bounding box
response = wfs.getfeature(typename=dataset,
                          bbox=(bbox1), #subset to the Study area ( based on bbox params)
                          outputFormat='application/json')

# Write it to a GeoJson file
with open(f'data/{dataset.replace(":","_")}.json', 'wb') as outfile:
    outfile.write(response.read())
response.close()

# Read the GeoJson file using GeoPandas
import geopandas as gpd
gdf = gpd.read_file(f'data/{dataset.replace(":","_")}.json')
gdf
# Out:
#                     id         country                                   name  \
# 0      windfarmspoly.1          Sweden                      Stora Middelgrund
# 1      windfarmspoly.2          Sweden                            Lovstaviken
# 2      windfarmspoly.3          Sweden                     Kattegatt Offshore
# 3      windfarmspoly.5  United Kingdom                        Islay Demo Zone
# 4      windfarmspoly.6  United Kingdom                North West Lewis (30MW)
# ..                 ...             ...                                    ...
# 557  windfarmspoly.551  United Kingdom                                Culzean
# 558  windfarmspoly.552  United Kingdom                                   Judy
# 559  windfarmspoly.568  United Kingdom  Offshore Wind Leasing Round 5 - PDA 1
# 560  windfarmspoly.569  United Kingdom  Offshore Wind Leasing Round 5 - PDA 2
# 561  windfarmspoly.570  United Kingdom                               Sinclair
#
#      n_turbines  power_mw      status year     dist_coast   area_sqkm notes  \
# 0         108.0     864.0     Planned  NaN   24805.731113   59.826131   NaN
# 1           5.0      11.5  Production  NaN       0.000000    0.193854   NaN
# 2          50.0     282.0    Approved  NaN    6381.649369   22.111037   NaN
# 3          10.0      10.0    Approved  NaN    1122.942248   27.611537   NaN
# 4          30.0      30.0     Planned  NaN       0.000000   51.062081   NaN
# ..          ...       ...         ...  ...            ...         ...   ...
# 557         NaN       3.0     Planned  NaN  221021.383044    2.001045   NaN
# 558         NaN      15.0     Planned  NaN  259624.252434    8.045883   NaN
# 559         NaN       0.0     Planned  NaN   35824.936586  369.050704   NaN
# 560         NaN       0.0     Planned  NaN   58291.392216  357.532494   NaN
# 561         NaN     100.0     Planned  NaN   58700.697705   24.914015   NaN
#
#                                               geometry
# 0    MULTIPOLYGON (((12.03532 56.65295, 12.06134 56...
# 1    MULTIPOLYGON (((12.46710 56.89015, 12.47244 56...
# 2    MULTIPOLYGON (((12.33361 56.86036, 12.34738 56...
# 3    MULTIPOLYGON (((-6.52572 55.65146, -6.55948 55...
# 4    MULTIPOLYGON (((-6.58016 58.36416, -6.58043 58...
# ..                                                 ...
# 557  MULTIPOLYGON (((1.87627 57.19864, 1.87668 57.1...
# 558  MULTIPOLYGON (((2.27045 56.67040, 2.27103 56.6...
# 559  MULTIPOLYGON (((-5.61768 51.23197, -5.61767 51...
# 560  MULTIPOLYGON (((-5.61767 51.21310, -5.61767 51...
# 561  MULTIPOLYGON (((-1.77221 58.24662, -1.77068 58...
#
# [562 rows x 11 columns]

# %% [markdown]
# ### SETUP basemap

# %%
Bathy = WebMapService('https://ows.emodnet-bathymetry.eu/ows', version= '1.3.0')

# %%
[op.name for op in Bathy.operations]
# Out:
# ['GetCapabilities', 'GetMap', 'GetFeatureInfo']

# %%
Bathy.getOperationByName('GetMap').formatOptions
# Out:
# ['image/png',
#  'application/atom+xml',
#  'application/json;type=utfgrid',
#  'application/pdf',
#  'application/rss+xml',
#  'application/vnd.google-earth.kml+xml',
#  'application/vnd.google-earth.kml+xml;mode=networklink',
#  'application/vnd.google-earth.kmz',
#  'image/geotiff',
#  'image/geotiff8',
#  'image/gif',
#  'image/jpeg',
#  'image/png; mode=8bit',
#  'image/svg+xml',
#  'image/tiff',
#  'image/tiff8',
#  'image/vnd.jpeg-png',
#  'image/vnd.jpeg-png8',
#  'text/html; subtype=openlayers',
#  'text/html; subtype=openlayers2',
#  'text/html; subtype=openlayers3']

# %% [markdown]
# ## Get a coastlines basemap for plotting:

# %%
import os
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

Bmap = Bathy['coastlines']
save_path = 'data/'
def getMap(filename, bbox, layerName):
    Bathy.getOperationByName('GetMap').formatOptions
    img = Bathy.getmap(layers= layerName,
                 size=(1200,600), 
                 srs='EPSG:4326',
                 bbox=bbox,
                 format='image/png',
                 style='contour',
                 transparent=True)

# Write the image to a temporary file
    out = open(os.path.join(save_path, filename), 'wb')
    out.write(img.read())
    out.close()  

# Define the layers to be used for the image, 
# here we use the multicolor bathymery dataset.
getMap(
    layerName=['coastlines'],
    bbox=(bbox1),
    filename = 'Basemap.png'
)
#read the image
image=mpimg.imread('data/Basemap.png')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image representing the basemap
basemap_img = mpimg.imread('data/Basemap.png')

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(9, 8))

# Plot the basemap image using imshow
ax.imshow(basemap_img, extent=[bbox1[0],  bbox1[2], bbox1[1], bbox1[3]]) 

# Plot the data on top of the basemap
gdf.plot(column='status',                                       # Specify the column in which the data you need to plot is located
         categorical=False,
         cmap='RdYlGn',
         legend=True,
         legend_kwds={'loc': 'lower right'},
         alpha=1,
         ax=ax) 

# Set title and limits
ax.set_title('Offshore Wind Farm Projects in European waters', fontsize=20)
ax.set_xlim(bbox1[0], bbox1[2]) 
ax.set_ylim(bbox1[1], bbox1[3]) 

plt.show()
# Out:
# c:\Users\matteo.mikos\AppData\Local\anaconda3\envs\ogc_workshop\Lib\site-packages\geopandas\plotting.py:732: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):

# %% [markdown]
# #### Subset data by attributes using [OGC Filter Encoding](https://www.ogc.org/standards/filter)

# %%
#Import the Filter encoding standard
import owslib.fes as fes 
from owslib.etree import etree

# Build a filter
sa_filter = fes.PropertyIsEqualTo(propertyname='status', literal='Planned') # Planned Windfarm projects
fid_filter = fes.PropertyIsBetween(propertyname='area_sqkm', lower = 1000, upper= 100000) # filter for projects bigger than 1000Km²
filter = fes.And([sa_filter,fid_filter]) # combine both filtering parameters using "AND"

# Get an xml representation of the filter
filterxml = etree.tostring(filter.toXML()).decode("utf-8")

# Pass it to getFeature
response = wfs.getfeature(typename=dataset,
                        outputFormat='application/json',
                        filter=filterxml)

# Write it to a GeoJson file
with open(f'data/{dataset.replace(":","_")}_filtered.json', 'wb') as outfile:
    outfile.write(response.read())
response.close()

# Read the GeoJson file using GeoPandas
gdf = gpd.read_file(f'data/{dataset.replace(":","_")}_filtered.json')
gdf
# Out:
#                    id         country  \
# 0   windfarmspoly.286  United Kingdom
# 1   windfarmspoly.287  United Kingdom
# 2   windfarmspoly.289  United Kingdom
# 3   windfarmspoly.290  United Kingdom
# 4   windfarmspoly.440         Denmark
# 5    windfarmspoly.40         Denmark
# 6    windfarmspoly.48         Denmark
# 7    windfarmspoly.36         Denmark
# 8    windfarmspoly.44         Denmark
# 9    windfarmspoly.81     Netherlands
# 10  windfarmspoly.133         Ireland
# 11  windfarmspoly.438         Finland
# 12  windfarmspoly.439         Finland
# 13  windfarmspoly.441         Denmark
# 14  windfarmspoly.507           Spain
# 15  windfarmspoly.519         Estonia
#
#                                           name  n_turbines  power_mw   status  \
# 0                                           N3         NaN       0.0  Planned
# 1                                           N1         NaN       0.0  Planned
# 2                                           E2         NaN       0.0  Planned
# 3                                           E1         NaN       0.0  Planned
# 4                                          NaN         NaN       0.0  Planned
# 5                                  Nordsren II         NaN       0.0  Planned
# 6                                   Nordsren I         NaN       0.0  Planned
# 7                            Nordsren III vest         NaN       0.0  Planned
# 8                                 Nordsren III         NaN       0.0  Planned
# 9                                 IJmuiden Ver         NaN    4000.0  Planned
# 10  Inis Ealge Marine Energy Park - DP Ireland         NaN       0.0  Planned
# 11                                         NaN         NaN       0.0  Planned
# 12                                         NaN         NaN       0.0  Planned
# 13                                         NaN         NaN       0.0  Planned
# 14                                 ZAPER_NOR_2         NaN       0.0  Planned
# 15                                         NaN         NaN       0.0  Planned
#
#     year     dist_coast     area_sqkm  notes  \
# 0   2020    9457.333545   1106.354044    NaN
# 1   2020    3171.943570   1162.427300    NaN
# 2   2020   59706.165817   1291.429348    NaN
# 3   2020   56455.635331   3743.866036    NaN
# 4    NaN    5000.551370  10079.276602    NaN
# 5    NaN   49194.172947   1872.941410    NaN
# 6    NaN   19964.419331   3176.148975    NaN
# 7    NaN  109379.688310   4484.323143    NaN
# 8    NaN   73863.316263   1642.587692    NaN
# 9    NaN   49466.898142   1172.060155    NaN
# 10   NaN       0.000000   1009.408557    NaN
# 11   NaN    6150.131138   1007.154648    NaN
# 12   NaN    6150.131138   1007.154648    NaN
# 13   NaN       0.000000   5713.909591    NaN
# 14   NaN   28752.000636   1807.819544    NaN
# 15   NaN    9903.634178   1217.896092    NaN
#
#                                              geometry
# 0   MULTIPOLYGON (((-6.32441 59.05853, -6.31226 59...
# 1   MULTIPOLYGON (((-4.10739 59.13575, -4.09759 59...
# 2   MULTIPOLYGON (((-0.50129 57.47805, -0.48542 57...
# 3   MULTIPOLYGON (((-0.47392 56.91518, -0.45823 56...
# 4   MULTIPOLYGON (((14.60980 55.11517, 14.60971 55...
# 5   MULTIPOLYGON (((6.41926 55.80585, 6.41538 55.8...
# 6   MULTIPOLYGON (((7.79172 56.37805, 7.79165 56.3...
# 7   MULTIPOLYGON (((6.33084 56.44456, 6.32952 56.4...
# 8   MULTIPOLYGON (((6.51131 56.88091, 6.54150 56.8...
# 9   MULTIPOLYGON (((3.74863 53.16913, 3.74864 53.0...
# 10  MULTIPOLYGON (((-7.49680 52.06100, -7.49660 52...
# 11  MULTIPOLYGON (((20.60960 59.50261, 20.38395 59...
# 12  MULTIPOLYGON (((20.60960 59.50261, 20.38395 59...
# 13  MULTIPOLYGON (((11.76105 54.53160, 11.76105 54...
# 14  MULTIPOLYGON (((-8.67734 43.76666, -8.99647 43...
# 15  MULTIPOLYGON (((21.69848 57.84691, 21.65391 57...

# %% [markdown]
# ## Change basemap to emodnet streetmap from bathy

# %%
fig, ax = plt.subplots(1, figsize=(8,6))

# Plot the basemap image using imshow
ax.imshow(basemap_img, extent=[bbox1[0],  bbox1[2], bbox1[1], bbox1[3]])

#Plot the dataset
gdf.plot(column='status',
         categorical = False,
         cmap='RdYlGn',
         legend= True,
         legend_kwds={'loc': 'lower right'},
         alpha = 1,
         ax=ax)
ax.set_title('Planned offshore wind farm projects\n larger than 1000 km²',fontsize=18)

#Set the map limits based on the bbox params to zoom in on your dataset
ax.set_xlim(bbox1[0],bbox1[2]) 
ax.set_ylim(bbox1[1],bbox1[3])
# Out:
# c:\Users\matteo.mikos\AppData\Local\anaconda3\envs\ogc_workshop\Lib\site-packages\geopandas\plotting.py:732: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):
# (39.712947845458984, 65.59857177734375)

# %% [markdown]
# ## Example 2: Combining Subset of WFS request with a WCS (Web Coverage Services) request
# ### 1. Define a new study area

# %% [markdown]
# In this example, we will be looking to subset the _"Modelled occurrence probability for coralligenous habitats of the Mediterranean sea"_ dataset obtained from Seabed Habitats thematic of EMODnet, to the marine region of the Western Mediterranean sea (as defined by ICES Ecoregions).

# %% [markdown]
# #### 1.1 Connect to the MarineRegions.org WebFeatureService
# Marine Regions is an integration of the VLIMAR Gazetteer and the VLIZ Maritime Boundaries Geodatabase. The VLIMAR Gazetteer is a database with geographic, mainly marine names such as seas, sandbanks, seamounts, ridges, bays or even standard sampling stations used in marine research. It is accessible at: https://www.marineregions.org/gazetteer.php?p=search

# %%
wfs2 = WebFeatureService('https://geo.vliz.be/geoserver/MarineRegions/wfs', version= '1.1.0')

#Inspect available datasets
print(wfs2.identification.type)
print(wfs2.identification.version)
print(wfs2.identification.title)
print(wfs2.identification.abstract)
list(wfs2.contents)
# Out:
# WFS
# 1.1.0
# Flanders Marine Institute (VLIZ) - WFS Service
# This is the reference implementation of OGC WFS 1.0.0 and WFS 1.1.0, supports all WFS operations including Transaction.
# ['MarineRegions:eez_archipelagic_waters',
#  'MarineRegions:arcticmarineareas',
#  'MarineRegions:brasdorlakebiospherereserve',
#  'MarineRegions:isa_ccz_managementarea',
#  'MarineRegions:coasts_subnational',
#  'MarineRegions:coasts_per_ocean',
#  'MarineRegions:eez_24nm',
#  'MarineRegions:comarge',
#  'MarineRegions:cross_dateline_polygons',
#  'MarineRegions:eca_reg13_nox',
#  'MarineRegions:eca_reg14_sox_pm',
#  'MarineRegions:eez',
#  'MarineRegions:ecs',
#  'MarineRegions:ecs_boundaries',
#  'MarineRegions:fadaregions',
#  'MarineRegions:fao',
#  'MarineRegions:tnc_wwf_feow_hydrosheds',
#  'MarineRegions:gsas_mediterraneanfishingzones',
#  'MarineRegions:longhurst',
#  'MarineRegions:goas',
#  'MarineRegions:haedatgrids_polygon',
#  'MarineRegions:high_seas',
#  'MarineRegions:ices_ecoregions',
#  'MarineRegions:ices_areas',
#  'MarineRegions:ices_statistical_rectangles',
#  'MarineRegions:iho',
#  'MarineRegions:iho_quadrants_20150810',
#  'MarineRegions:eez_internal_waters',
#  'MarineRegions:itmarbiogeogsector_bianchi',
#  'MarineRegions:eez_land',
#  'MarineRegions:eez_iho_union_v2',
#  'MarineRegions:eez_boundaries',
#  'MarineRegions:mesopelagiczones',
#  'MarineRegions:gazetteer_line',
#  'MarineRegions:gazetteer_polygon',
#  'MarineRegions:world_countries_coasts',
#  'MarineRegions:na_coastalwaterbodies',
#  'MarineRegions:ospar_regions',
#  'MarineRegions:ospar_boundaries',
#  'MarineRegions:mra_nor_blocks',
#  'MarineRegions:mra_uk_blocks',
#  'MarineRegions:seavox_v16',
#  'MarineRegions:seavox_v17',
#  'MarineRegions:seavox_v18',
#  'MarineRegions:seavox_v19',
#  'MarineRegions:eez_12nm',
#  'MarineRegions:lme',
#  'MarineRegions:eez_iho',
#  'MarineRegions:worldheritagemarineprogramme_v1',
#  'MarineRegions:worldheritagemarineprogramme',
#  'MarineRegions:world_bay_gulf',
#  'MarineRegions:world_estuary_delta',
#  'MarineRegions:worldcountries_esri_2014',
#  'MarineRegions:land_v9']

# %%
#Define desired regional classification, here ICES Ecoregions
dataset2 = 'MarineRegions:ices_ecoregions'

# See available methods
[operation.name for operation in wfs2.operations]
# Out:
# ['GetCapabilities',
#  'DescribeFeatureType',
#  'GetFeature',
#  'GetGmlObject',
#  'LockFeature',
#  'GetFeatureWithLock',
#  'Transaction']

# %%
#Inspect ICES Ecoregions dataset
print(wfs2.contents[dataset2].title)
print(wfs2.contents[dataset2].abstract)
bbox = wfs2.contents[dataset2].boundingBoxWGS84
print (bbox)
# Out:
# ICES Ecoregions (2015)
# Delineation of the ICES Ecoregions was originally described in ICES Advice ACFM/ACE report(2004).
#
# In the present updated version, the delineation has been updated to account for additional policy objectives and reconciling of legislation (eg the MSFD and the EU water and habitats directives)
#
# The differences are based on the four principles:
# 1. Within the EU accept the MSFD regional and sub-regional definitions.
# 2. Separate Icelandic Seas from those around Greenland.
# 3. Use Large Marine Ecosystem units to define the Arctic Ocean.
# 4. Use the accepted Norwegian regional management plans definitions of the Norwegian and Barents Seas.
#
# The Ecoregions were proposed to assist the implementation of the ecosystem approach in European waters
# (-44.0000000000998, 30.2670495513959, 68.5000001347984, 90.0000000001001)

# %%
# Get the FeatureType’s schema via `DescribeFeatureType`
wfs2.get_schema(dataset2)
# Out:
# {'properties': {'objectid': 'int',
#   'ecoregion': 'string',
#   'mrgid': 'int',
#   'longitude': 'decimal',
#   'latitude': 'decimal',
#   'area_km2': 'decimal',
#   'placetype': 'string',
#   'placetypei': 'int',
#   'parent': 'string',
#   'parentid': 'int',
#   'source': 'string',
#   'sourceid': 'int',
#   'lon_min': 'decimal',
#   'lon_max': 'decimal',
#   'lat_min': 'decimal',
#   'lat_max': 'decimal'},
#  'required': [],
#  'geometry': 'MultiPolygon',
#  'geometry_column': 'the_geom'}

# %% [markdown]
# #### 1.2 Inspect the ICES Ecoregions datasets
# Listing all available regional delimitations based on the ICES Ecoregions classification

# %%
response = wfs2.getfeature(typename=dataset2,
                          bbox=(bbox), 
                          outputFormat='application/json')

# Write it to a GeoJson file
with open(f'data/{dataset2.replace(":","_")}.json', 'wb') as outfile:
    outfile.write(response.read())
response.close()

# Read the GeoJson file using GeoPandas
import geopandas as gpd
gdf = gpd.read_file(f'data/{dataset2.replace(":","_")}.json')
gdf
# Out:
#                     id  objectid  \
# 0    ices_ecoregions.1         1
# 1    ices_ecoregions.2         2
# 2    ices_ecoregions.3         3
# 3    ices_ecoregions.4         4
# 4    ices_ecoregions.5         5
# 5    ices_ecoregions.6         6
# 6    ices_ecoregions.7         7
# 7    ices_ecoregions.8         8
# 8    ices_ecoregions.9         9
# 9   ices_ecoregions.10        10
# 10  ices_ecoregions.12        12
# 11  ices_ecoregions.13        13
# 12  ices_ecoregions.14        14
# 13  ices_ecoregions.15        15
# 14  ices_ecoregions.16        16
# 15  ices_ecoregions.17        17
# 16  ices_ecoregions.11        11
#
#                                        ecoregion  mrgid  longitude   latitude  \
# 0                                  Greenland Sea  36310 -28.070627  69.670326
# 1            Bay of Biscay and the Iberian Coast  36311  -8.886815  42.662908
# 2                                         Azores  36312 -28.438624  39.154203
# 3                      Western Mediterranean Sea  22167   6.109270  39.531134
# 4   Ionian Sea and the Central Mediterranean Sea  36313  17.320194  35.190387
# 5                                      Black Sea  22172  34.262870  43.464598
# 6                                   Adriatic Sea  36314  16.118553  42.714787
# 7                           Aegean-Levantine Sea  22169  28.686066  34.822184
# 8                                    Celtic Seas  22173  -9.264609  54.591504
# 9                                     Baltic Sea  22170  19.497017  58.713587
# 10                                  Arctic Ocean  36315  11.178360  85.665237
# 11                                   Iceland Sea  36316 -18.921173  64.634624
# 12                                   Barents Sea  22162  36.343739  75.260031
# 13                                        Faroes  22161  -7.183476  62.578992
# 14                                 Norwegian Sea  22164   2.389611  70.232395
# 15                    Oceanic Northeast Atlantic  22166 -27.561575  48.708945
# 16                             Greater North Sea  36317   2.932991  56.011900
#
#         area_km2       placetype  placetypei           parent  parentid  \
# 0   1.065385e+06  ICES Ecoregion         246  ICES Ecoregions     22540
# 1   7.557796e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 2   7.928794e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 3   8.444074e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 4   7.726428e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 5   4.747685e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 6   1.392988e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 7   7.567145e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 8   9.177512e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 9   3.999565e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 10  6.359402e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 11  7.563617e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 12  2.126450e+06  ICES Ecoregion         246  ICES Ecoregions     22540
# 13  2.672277e+05  ICES Ecoregion         246  ICES Ecoregions     22540
# 14  1.206188e+06  ICES Ecoregion         246  ICES Ecoregions     22540
# 15  4.753194e+06  ICES Ecoregion         246  ICES Ecoregions     22540
# 16  6.708331e+05  ICES Ecoregion         246  ICES Ecoregions     22540
#
#    source  sourceid    lon_min    lon_max    lat_min    lat_max  \
# 0    ICES       378 -44.000000   5.677908  56.560460  82.304253
# 1    ICES       378 -13.861560  -0.146245  36.000000  48.000002
# 2    ICES       378 -35.579300 -20.855320  36.000000  43.067630
# 3    ICES       378  -5.600000  16.223122  35.070668  44.427203
# 4    ICES       378  10.015849  24.122811  30.267050  40.520659
# 5    ICES       378  26.175552  42.354960  39.998909  47.376395
# 6    ICES       378  12.065226  20.020828  39.744192  45.808914
# 7    ICES       378  22.149885  36.215729  30.756594  41.091326
# 8    ICES       378 -16.090850   1.806284  48.000002  63.890844
# 9    ICES       378   9.419914  31.685704  52.871122  67.080588
# 10   ICES       378 -40.000000  68.500000  80.573675  90.000000
# 11   ICES       378 -30.863334  -5.557446  59.963399  69.583333
# 12   ICES       378   0.833790  68.500000  61.941305  82.970055
# 13   ICES       378 -13.909697  -0.484345  59.944713  65.694080
# 14   ICES       378 -13.629556  17.900159  62.000001  80.833862
# 15   ICES       378 -42.000000  -9.368772  36.000000  63.313333
# 16   ICES       378  -5.000000  13.062911  48.000002  62.000003
#
#                                              geometry
# 0   MULTIPOLYGON (((-43.99177 60.29694, -44.00000 ...
# 1   MULTIPOLYGON (((-5.60000 36.01104, -5.60000 36...
# 2   MULTIPOLYGON (((-21.05878 36.00000, -23.49448 ...
# 3   MULTIPOLYGON (((2.99963 43.14220, 2.99973 43.1...
# 4   MULTIPOLYGON (((24.12281 34.80180, 24.12272 34...
# 5   MULTIPOLYGON (((41.58356 42.40528, 41.57035 42...
# 6   MULTIPOLYGON (((19.99367 39.79384, 19.99293 39...
# 7   MULTIPOLYGON (((25.74529 36.79303, 25.74350 36...
# 8   MULTIPOLYGON (((1.37123 62.00000, 1.37123 62.0...
# 9   MULTIPOLYGON (((11.07890 53.14186, 11.09182 53...
# 10  MULTIPOLYGON (((68.50000 82.97005, 68.05861 82...
# 11  MULTIPOLYGON (((-21.72000 63.84772, -21.71718 ...
# 12  MULTIPOLYGON (((39.12844 61.95031, 39.13307 61...
# 13  MULTIPOLYGON (((-0.48933 63.89084, -0.49057 63...
# 14  MULTIPOLYGON (((9.84627 63.31005, 9.84375 63.3...
# 15  MULTIPOLYGON (((-13.90970 60.82639, -13.27398 ...
# 16  MULTIPOLYGON (((-4.56139 48.00000, -4.56354 48...

# %% [markdown]
# #### 1.3 Write a filter to select the desired region (Greater North Sea)

# %%
#Import the Filter encoding standard
import owslib.fes as fes 
from owslib.etree import etree

# Build a filter
filter = fes.PropertyIsEqualTo(propertyname='ecoregion', literal='Western Mediterranean Sea') # Specifying the needed Ecoregion

# Get an xml representation of the filter
filterxml = etree.tostring(filter.toXML()).decode("utf-8")

# Pass it to getFeature
response = wfs2.getfeature(typename = dataset2,
                        outputFormat='application/json',
                        filter=filterxml)

# Write it to a GeoJson file
with open(f'data/{dataset2.replace(":","_")}_filtered.json', 'wb') as outfile:
    outfile.write(response.read())
response.close()

# Read the GeoJson file using GeoPandas
Study_area = gpd.read_file(f'data/{dataset2.replace(":","_")}_filtered.json')

# Plot and inspect the study area dataset
Study_area.plot()
Study_area
# Out:
#                   id  objectid                  ecoregion  mrgid  longitude  \
# 0  ices_ecoregions.4         4  Western Mediterranean Sea  22167    6.10927
#
#     latitude       area_km2       placetype  placetypei           parent  \
# 0  39.531134  844407.444602  ICES Ecoregion         246  ICES Ecoregions
#
#    parentid source  sourceid  lon_min    lon_max    lat_min    lat_max  \
# 0     22540   ICES       378     -5.6  16.223122  35.070668  44.427203
#
#                                             geometry
# 0  MULTIPOLYGON (((2.99963 43.14220, 2.99973 43.1...

# %% [markdown]
# ### 3.2 Get raster data with WCS connecting to the Seabed Habitats Thematic of EMODnet

# %% [markdown]
# #### <i>Create a WebCoverageService (WCS) object</i>

# %%
wcs = WebCoverageService('https://ows.emodnet-seabedhabitats.eu/geoserver/emodnet_open_maplibrary/wcs', version = '1.0.0')

# %% [markdown]
# #### <i>Get a list of available coverages</i>

# %%
for coverage_name in wcs.contents.keys():
    print(coverage_name)
# Out:
# emodnet_open_maplibrary:Corine_2018_Coastal_Wetlands_WGS84
# emodnet_open_maplibrary:Modiolus_habitatsuitabilitymodel_uk_50
# emodnet_open_maplibrary:Sabellaria_habitatsuitabilitymodel_uk_50
# emodnet_open_maplibrary:Zostera_habitatsuitabilitymodel_uk_50
# emodnet_open_maplibrary:LAMpred_Nordic
# emodnet_open_maplibrary:SACpred_Nordic
# emodnet_open_maplibrary:mediseh_cora
# emodnet_open_maplibrary:mediseh_maerl
# emodnet_open_maplibrary:mediseh_posidonia
# emodnet_open_maplibrary:DK004008_EFH_Cod_Spawning grounds
# emodnet_open_maplibrary:DK004009_EFH_Cod_Feeding grounds
# emodnet_open_maplibrary:DK004010_EFH_Cod_Nursery grounds
# emodnet_open_maplibrary:DK004011_EFH_Plaice_Spawning grounds
# emodnet_open_maplibrary:DK004012_EFH_Plaice_Feeding grounds
# emodnet_open_maplibrary:DK004013_EFH_Plaice_Nursery grounds
# emodnet_open_maplibrary:DK004014_EFH_Sole_Feeding grounds
# emodnet_open_maplibrary:DK004015_EFH_Sole_Nursery grounds
# emodnet_open_maplibrary:DK004016_EFH_Turbot_Feeding grounds
# emodnet_open_maplibrary:DK004017_EFH_Flounder_Spawning grounds
# emodnet_open_maplibrary:DK004018_EFH_Flounder_Feeding grounds
# emodnet_open_maplibrary:DK004019_EFH_Flounder_Nursery grounds
# emodnet_open_maplibrary:DK004020_EFH_Herring_Feeding grounds
# emodnet_open_maplibrary:DK004021_EFH_Herring_Nursery grounds
# emodnet_open_maplibrary:DK004022_EFH_Sprat_Feeding grounds
# emodnet_open_maplibrary:ES005001
# emodnet_open_maplibrary:ES005002
# emodnet_open_maplibrary:ES005003
# emodnet_open_maplibrary:ES005004
# emodnet_open_maplibrary:ES005005
# emodnet_open_maplibrary:ES005006
# emodnet_open_maplibrary:ES005007
# emodnet_open_maplibrary:ES005008
# emodnet_open_maplibrary:fi004001
# emodnet_open_maplibrary:fi004002
# emodnet_open_maplibrary:fi004003
# emodnet_open_maplibrary:fi004004
# emodnet_open_maplibrary:fi004005
# emodnet_open_maplibrary:fi004006
# emodnet_open_maplibrary:fi004007
# emodnet_open_maplibrary:fi004008
# emodnet_open_maplibrary:GB300015_model
# emodnet_open_maplibrary:GB300016_model
# emodnet_open_maplibrary:GB300017_model
# emodnet_open_maplibrary:GB300018_model
# emodnet_open_maplibrary:GB300019_model
# emodnet_open_maplibrary:GB300020_model
# emodnet_open_maplibrary:GB300021_model
# emodnet_open_maplibrary:GB300022_model
# emodnet_open_maplibrary:PT004002
# emodnet_open_maplibrary:PT004003
# emodnet_open_maplibrary:PT004004
# emodnet_open_maplibrary:PT004005

# %% [markdown]
# #### <i>Define the dataset</i>
# here we select the "modelled occurrence probability for coralligenous habitats of the Mediterranean sea" dataset

# %%
dataset = 'emodnet_open_maplibrary:mediseh_cora'

# %% [markdown]
# #### <i>Retrieve a list of available properties of a coverage</i>

# %%
for item in dir(wcs.contents[dataset]):
    if "_" not in item:
        print(item)
# Out:
# abstract
# axisDescriptions
# boundingBox
# boundingBoxWGS84
# boundingboxes
# crsOptions
# defaulttimeposition
# grid
# id
# keywords
# styles
# supportedCRS
# supportedFormats
# timelimits
# timepositions
# title

# %% [markdown]
# #### <i>Retrieve grid property information</i>

# %%
for item in dir(wcs.contents[dataset].grid):
    if "_" not in item:
        print(item + ": " + str(wcs.contents[dataset].grid.__dict__[item]))
# Out:
# axislabels: ['X', 'Y']
# dimension: 2
# highlimits: ['13781', '6398']
# lowlimits: ['0', '0']
# offsetvectors: [['400.0', '0.0'], ['0.0', '-400.0']]
# origin: ['-729757.059693927', '5991106.766843']

# %% [markdown]
# #### Get geo-bounding boxes and native CRS

# %%
print(wcs.contents[dataset].boundingBoxWGS84)
print(wcs.contents[dataset].supportedCRS)
# Out:
# (-6.557315834740004, 29.4395189039463, 42.96500914820098, 47.30077271849997)
# [urn:ogc:def:crs:EPSG::3857]

# %% [markdown]
# #### Retrieve supported formats

# %%
wcs.contents[dataset].supportedFormats
# Out:
# ['ArcGrid',
#  'GeoTIFF',
#  'GIF',
#  'GeoPackage (mosaic)',
#  'Gtopo30',
#  'ImageMosaic',
#  'JPEG',
#  'PNG',
#  'TIFF']

# %% [markdown]
# #### Subset and download raster data using a GetCoverage request

# %%
# get parameters for grid
bbox2 = Study_area.bounds.values[0].tolist() # get bbox for the Greater North Sea study area 
crs2 = Study_area.crs.srs # get crs of the Study Area file
print(bbox2)
print(crs2)
# Out:
# [-5.6, 35.07066846, 16.22312212, 44.42720294]
# EPSG:4326

# %% [markdown]
# Optional Step: Manually adjust the Bounding Box of raster dataset, to cover an area sligthly larger than that of the study area.

# %%
#Adding 2 decimal degrees to each side of the bbox

bbox2 = wcs.contents[dataset].boundingBoxWGS84 #[bbox2[0]-2,bbox2[1]-2,bbox2[2]+2,bbox2[3]+2]
print(bbox2)
# Out:
# (-6.557315834740004, 29.4395189039463, 42.96500914820098, 47.30077271849997)

# %%
# GetCoverage request
response = wcs.getCoverage(identifier=dataset,
                           bbox=bbox2,
                           format='GeoTIFF',
                           crs=crs2,
                           resx=0.00833333,resy=0.00833333,
                           interpolation='bicubic')
print(response.geturl())
with open(f'data/{dataset.replace(":","_")}.tif','wb') as outfile:
    outfile.write(response.read())
# Out:
# https://ows.emodnet-seabedhabitats.eu/geoserver/emodnet_open_maplibrary/wcs?version=1.0.0&request=GetCoverage&service=WCS&Coverage=emodnet_open_maplibrary%3Amediseh_cora&BBox=-6.557315834740004%2C29.4395189039463%2C42.96500914820098%2C47.30077271849997&crs=EPSG%3A4326&format=GeoTIFF&resx=0.00833333&resy=0.00833333&interpolation=bicubic

# %% [markdown]
# #### Clip the raster dataset to the study area using rasterio

# %%
import rasterio
from rasterio import mask
from rasterio.plot import show

with rasterio.open(f'data/{dataset.replace(":","_")}.tif') as src:
    # Clip the raster using the study area geometry
    out_image, out_transform = rasterio.mask.mask(src, Study_area.geometry, crop=True)
    out_meta = src.meta
    
out_meta.update({"driver": "GTiff",
                 "height": out_image.shape[1],
                 "width": out_image.shape[2],
                 "transform": out_transform})

# Create a new raster file containing the clipped data
clipped_raster_path = f'data/{dataset.replace(":","_")}_clipped.tif'
with rasterio.open(clipped_raster_path, "w", **out_meta) as dest:
    dest.write(out_image)

# %%
import rioxarray
rasterdata = rioxarray.open_rasterio(f'data/{dataset.replace(":","_")}.tif')
rasterdata
# Out:
# <xarray.DataArray (band: 1, y: 2143, x: 5943)>
# [12735849 values with dtype=float32]
# Coordinates:
#   * band         (band) int32 1
#   * x            (x) float64 -6.553 -6.545 -6.536 -6.528 ... 42.94 42.95 42.96
#   * y            (y) float64 47.3 47.29 47.28 47.27 ... 29.47 29.46 29.45 29.44
#     spatial_ref  int32 0
# Attributes:
#     AREA_OR_POINT:           Area
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     TIFFTAG_XRESOLUTION:     1
#     TIFFTAG_YRESOLUTION:     1
#     _FillValue:              -3.4028235e+38
#     scale_factor:            1.0
#     add_offset:              0.0

# %% [markdown]
# #### Open the clipped rasterdata in an xarray object using the rasterio library

# %%
import rioxarray
rasterdata_clipped = rioxarray.open_rasterio(f'data/{dataset.replace(":","_")}_clipped.tif')
rasterdata_clipped
# Out:
# <xarray.DataArray (band: 1, y: 1124, x: 2620)>
# [2944880 values with dtype=float32]
# Coordinates:
#   * band         (band) int32 1
#   * x            (x) float64 -5.603 -5.595 -5.587 -5.578 ... 16.2 16.21 16.22
#   * y            (y) float64 44.43 44.42 44.41 44.4 ... 35.09 35.09 35.08 35.07
#     spatial_ref  int32 0
# Attributes:
#     AREA_OR_POINT:  Area
#     _FillValue:     -3.4028235e+38
#     scale_factor:   1.0
#     add_offset:     0.0

# %% [markdown]
# #### Plot a map of the rasterdata overlaid with the study area
#
# This Time we will use Cartopy features to plot the basemap.

# %%
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs


fig = plt.figure(figsize=(8,10))# Increase the figure size
ax = fig.add_subplot(111, projection=ccrs.PlateCarree())

#add Basemap features from Cartopy
ax.add_feature(cartopy.feature.OCEAN, )
ax.add_feature(cartopy.feature.LAND)
ax.add_feature(cartopy.feature.BORDERS, linestyle=':')
ax.coastlines(resolution='10m')

#plot the data
cbar_kwargs = {'shrink':0.5, 'extend': 'neither'}                                                             
rasterdata.plot(ax = ax, cmap = 'Greens', vmin = 0 , vmax = 1, cbar_kwargs = cbar_kwargs) # plot raster data
Study_area.boundary.plot(ax=ax, color=None, edgecolor = 'red',linewidth=0.8 , label = 'Study Area')

ax.set_title('Modelled occurrence probability for coralligenous \n habitats in the Western Mediterranean Sea', fontsize=15)


# Close the raster file after plotting
rasterdata_clipped.close()

# Now you can safely delete the file if needed
# Out:
# c:\Users\matteo.mikos\AppData\Local\anaconda3\envs\ogc_workshop\Lib\site-packages\matplotlib\colors.py:718: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N
# c:\Users\matteo.mikos\AppData\Local\anaconda3\envs\ogc_workshop\Lib\site-packages\matplotlib\colors.py:718: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N
# c:\Users\matteo.mikos\AppData\Local\anaconda3\envs\ogc_workshop\Lib\site-packages\matplotlib\colors.py:718: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N
# c:\Users\matteo.mikos\AppData\Local\anaconda3\envs\ogc_workshop\Lib\site-packages\matplotlib\colors.py:718: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N

# %% [markdown]
# ### [>> Next: Use OGC services from common GIS software](./4_OGC_services_from_common_GIS_software.ipynb)

# %% [markdown]
# <hr>

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img style="float: right" alt="Creative Commons Lizenzvertrag" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/88x31.png" /></a>
